# %%
pip install librosa soundfile numpy scikit-learn pyaudio
# Out:
# Requirement already satisfied: librosa in c:\users\mahip\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: soundfile in c:\users\mahip\anaconda3\lib\site-packages (0.13.1)
# Requirement already satisfied: numpy in c:\users\mahip\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\mahip\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: pyaudio in c:\users\mahip\anaconda3\lib\site-packages (0.2.14)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\mahip\anaconda3\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\mahip\anaconda3\lib\site-packages (from librosa) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\mahip\anaconda3\lib\site-packages (from librosa) (1.13.1)
# Requirement already satisfied: joblib>=1.0 in c:\users\mahip\anaconda3\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\mahip\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\mahip\anaconda3\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\mahip\anaconda3\lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\mahip\anaconda3\lib\site-packages (from librosa) (4.11.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\mahip\anaconda3\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\mahip\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: cffi>=1.0 in c:\users\mahip\anaconda3\lib\site-packages (from soundfile) (1.17.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\mahip\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: pycparser in c:\users\mahip\anaconda3\lib\site-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: packaging in c:\users\mahip\anaconda3\lib\site-packages (from lazy_loader>=0.1->librosa) (24.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\mahip\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\mahip\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\mahip\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mahip\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mahip\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mahip\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mahip\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import librosa
import soundfile
import os, glob, pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %%
# DataFlair - Extract features (mfcc, chroma, mel) from a sound file
def extract_feature(file_name, mfcc=True, chroma=True, mel=True):
    import numpy as np
    import librosa
    import soundfile

    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate = sound_file.samplerate
        result = np.array([])

        if chroma:
            stft = np.abs(librosa.stft(X))

        if mfcc:
            mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
            result = np.hstack((result, mfccs))

        if chroma:
            chroma_feat = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
            result = np.hstack((result, chroma_feat))

        if mel:
            mel_spec = np.mean(librosa.feature.melspectrogram(y=X, sr=sample_rate).T, axis=0)
            result = np.hstack((result, mel_spec))

    return result

# %%
#DataFlair - Emotions in the RAVDESS dataset
emotions={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}

#DataFlair - Emotions to observe
observed_emotions=['calm', 'happy', 'fearful', 'disgust']

# %%
#DataFlair - Load the data and extract features for each sound file
def load_data(test_size=0.2):
    x,y=[],[]
    for file in glob.glob("ravdess_data\\Actor_*\\*.wav"):
        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]]
        if emotion not in observed_emotions:
            continue
        feature=extract_feature(file, mfcc=True, chroma=True, mel=True)
        x.append(feature)
        y.append(emotion)
    return train_test_split(np.array(x), y, test_size=test_size, random_state=9)

# %%
#DataFlair - Split the dataset
x_train,x_test,y_train,y_test=load_data(test_size=0.25)

# %%
#DataFlair - Get the shape of the training and testing datasets
print((x_train.shape[0], x_test.shape[0]))
# Out:
# (576, 192)

# %%
#DataFlair - Get the number of features extracted
print(f'Features extracted: {x_train.shape[1]}')
# Out:
# Features extracted: 180

# %%
#DataFlair - Initialize the Multi Layer Perceptron Classifier
model=MLPClassifier(alpha=0.01, batch_size=256, epsilon=1e-08, hidden_layer_sizes=(300,), learning_rate='adaptive', max_iter=500)

# %%
#DataFlair - Train the model
model.fit(x_train,y_train)
# Out:
# MLPClassifier(alpha=0.01, batch_size=256, hidden_layer_sizes=(300,),
#               learning_rate='adaptive', max_iter=500)

# %%
#DataFlair - Predict for the test set
y_pred=model.predict(x_test)

# %%
#DataFlair - Calculate the accuracy of our model
accuracy=accuracy_score(y_true=y_test, y_pred=y_pred)

#DataFlair - Print the accuracy
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 57.29%

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Create the confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=model.classes_)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap='Blues', xticks_rotation=45)

plt.title("Confusion Matrix - Emotion Recognition")
plt.show()

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap='Blues', values_format=".2f")

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# Define the parameter grid
param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']
}

# Create a GridSearchCV object
grid = GridSearchCV(SVC(), param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)

# Fit to training data
grid.fit(x_train, y_train)

# Best parameters and score
print("Best Parameters:", grid.best_params_)
print("Best Accuracy:", grid.best_score_)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits

# %%
from sklearn.neural_network import MLPClassifier

param_grid = {
    'hidden_layer_sizes': [(50,), (100,), (100, 50)],
    'activation': ['tanh', 'relu'],
    'solver': ['adam'],
    'alpha': [0.0001, 0.001],
    'learning_rate': ['constant','adaptive']
}

grid = GridSearchCV(MLPClassifier(max_iter=500), param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)
grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)
print("Best Accuracy:", grid.best_score_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 11
#       1 from sklearn.neural_network import MLPClassifier
#       3 param_grid = {
#       4     'hidden_layer_sizes': [(50,), (100,), (100, 50)],
#       5     'activation': ['tanh', 'relu'],
#    (...)
#       8     'learning_rate': ['constant','adaptive']
#       9 }
# ---> 11 grid = GridSearchCV(MLPClassifier(max_iter=500), param_grid, cv=5, scoring='accuracy', verbose=2, n_jobs=-1)
#      12 grid.fit(X_train, y_train)
#      14 print("Best Parameters:", grid.best_params_)
#
# NameError: name 'GridSearchCV' is not defined
